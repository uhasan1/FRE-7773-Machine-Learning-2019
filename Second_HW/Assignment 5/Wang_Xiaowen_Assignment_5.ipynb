# %% [markdown]
# # Homework 5
# #### Assigned: 2019-04-26
# #### Due EOD: 2019-05-03
#
# Based on Lecture 12
# + The student fills in the <...> fields.
# + The student can create as many new cells as necessary in the solution sections.

# %% [markdown]
# **Make sure you have activated the correct python envorinment**

# %% [markdown]
# #### Name:  Xiaowen Wang
# #### NetID: xw1831

# %% [markdown]
# ## Problem 1 (20 points)

# %% [markdown]
# A CNN has the following structure:
#
# Conv2D_Layer -> Pooling_Layer -> Flattening_Layer -> Dense_Layer
#
# + input shape (size of the image): $M_1 \times M_2$
# + conv2d kernel with bias
# + conv2d kernel shape: $K_1 \times K_2$
# + conv2d padding: same
# + conv2d stride in both dimensions: 1
# + conv2d filters (number of kernels): $F$
# + pooling layer size: $P_1 \times P_2$ (assume $P_{1,2}$ is a divisor of $M_{1,2}$)
# + pooling padding: same
# + pooling stride in both dimensions: 1
# + flattening layer
# + dense layer with bias
# + dense layer units (number of nodes): $H$
#
# Write down the expression that gives the total number of parameters to be fitted $Q$ in terms of the above values.

# %% [markdown]
# ## Solution 1

# %% [markdown]
# Conv2D_Layer Parameters:
# $$N_1=(K_1\times K_2 +1)\times F$$
# Pooling_Layer Output Shape:
# $$(M_1-P_1+1)\times(M_2-P_2+1)$$
# Flattening_Layer Output:
# $$N_2=(M_1-P_1+1)\times(M_2-P_2+1)\times F$$
# Dense_Layer Parameters:
# $$N_3=H\times (N_2+1)$$
# **Total number of parameters**:
# \begin{equation}
# \begin{aligned}
# Q&=N_1+N_3\\
# &=(K_1\times K_2 +1)\times F+[(M_1-P_1+1)\times(M_2-P_2+1)\times F+1]\times H\\
# &=[(K_1\times K_2 +1)+(M_1-P_1+1)\times(M_2-P_2+1)\times H]\times F+H
# \end{aligned}
# \end{equation}

# %% [markdown]
# ## Problem 2 (80 points)
#
# Use LSTM to analyze S&P 500 returns over the period 2004-2006.
#
# The data file "stock-treasury-2004_2006.csv", to be found in the "Data" folder, contains the following:
# + TREAS_3M: the yield of the 3-month treasury note in percent (i.e 2.1 means 2.1%)
# + Adjusted close price of ten major stocks: GM, F, UTX, CAT, MRK, PFE, IBM, MSFT, C, XOM
# + SP: The S&P 500 equity index level at the close of the trading day
#
# **Do the following:**
#
# Use the pandas read_csv function to read the Date and SP columns in a data frame called "sp_df".
# Rename the "SP" column into "ClosePx" in the same read_csv call.
# Compute the close-to-close index returns as:  $r_t = P_{t+1}/P_t - 1$ and add them as a new column "DailyRet".
# It is recommended to express all daily returns in basis points (10,000 bps = 100% = 1)
#
# We want to train an RNN that looks back $M$ days and forecasts forward $N$ days.
# Therefore the RNN will use return sequences of size $M$, and targets of size $N$.
#
# Reformat the return data suitable for RNN processing as follows.
# From the "DailyRet" column of "sp_df", create a data input matrix $X$ containing rows as below:
# $$r_0, r_1, r_2, \ldots, r_{M-1}$$
# $$r_1, r_2, r_3, \ldots, r_{M}$$
# $$r_2, r_3, r_4, \ldots, r_{M+1}$$
# $$\ldots$$
# From the "DailyRet" column of "sp_df", create also a target matrix $y$ containing rows as below:
# $$ r_{M}, r_{M+1}, \ldots, r_{M+N-1}$$
# $$ r_{M+1}, r_{M+2}, \ldots, r_{M+N}$$
# $$ r_{M+2}, r_{M+3}, \ldots, r_{M+N+1}$$
# $$\ldots$$
#
# Set $M=16$ and $N=4$.
# Build an RNN with two LSTM cells and train it on the first 607 sequences.
# This means that the training set contains returns with the latest date of 2016-05-31.
# Use the remaining returns for out-of-sample testing.
# This is a regression task, so train the network using mean_squared_error loss.
# When connecting the two LSTMs, make sure you set the parameter return_sequences=True on the first LSTM,
# so that the second can see the sequences.
#
# Compute the out-of-sample actual and predicted 2-day, 3-day, ..., N-day return, by summing 1-day forward returns up to this horizon.
# N-day return is the return from today's close to the close of the N-th day forward from today.
# Calculate and report the RMSE and the correlation between actual and predicted 1-day, 2-day, ..., N-day returns.
# Plot the actual and predicted returns in the out-of-sample part.
# What do you conclude regarding the quality of the forecasts?

# %% [markdown]
# ## Solution 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import os
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

sp_df = pd.read_csv(os.path.join(os.getcwd(), "stock-treasury-2004_2006.csv"), usecols=[0,12],names=['Date', 'ClosePx'],header=0)

# Compute the close-to-close index returns and express all daily returns in basis points.
sp_df['DailyRet']=sp_df['ClosePx'].pct_change(1)*10000
sp_df=sp_df[1:] # Remove nan value

# %%
sp_df.head(5)
# Out:
#         Date  ClosePx    DailyRet
# 1  05-Jan-04  1122.22  123.953522
# 2  06-Jan-04  1123.67   12.920818
# 3  07-Jan-04  1126.33   23.672431
# 4  08-Jan-04  1131.92   49.630215
# 5  09-Jan-04  1121.86  -88.875539

# %% [markdown]
# ### Reshape and normalize the input data

# %%
# Standardize Series Data due to the sensitivity of 
temp = sp_df.DailyRet.values.reshape(-1,1)
temp = StandardScaler().fit_transform(temp)

X_size, y_size = 16, 4
X_train, y_train = [], []

# create input matrix X and target matrix y
for i in range(X_size, 607):
    X_train.append(temp[i-X_size:i,0])
    y_train.append(temp[i:i+y_size,0])
    
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
# Check the input and output shape for LSTM.
print('The shape of input matrix X is {}'.format(X_train.shape))
print('The shape of target matrix y is {}'.format(y_train.shape))
# Out:
# The shape of input matrix X is (591, 16, 1)
# The shape of target matrix y is (591, 4)

# %% [markdown]
# ### Construct the LSTM

# %%
from keras.models import Sequential
from keras.layers import LSTM, SimpleRNN
from keras.layers import Dense, Dropout
from sklearn.metrics import mean_squared_error

# %%
rnn_input_shape = (X_train.shape[1], 1)
n_units=20
rnn_drop_rate = 0.4

rnn = Sequential()
rnn.add(LSTM(input_shape=rnn_input_shape, units=n_units, activation='relu',return_sequences = True))
rnn.add(Dropout(rnn_drop_rate))
rnn.add(LSTM(input_shape=rnn_input_shape, units=n_units, activation='relu'))
rnn.add(Dropout(rnn_drop_rate))
rnn.add(Dense(4))
rnn.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 16, 20)            1760
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 20)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 20)                3280
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 84
# =================================================================
# Total params: 5,124
# Trainable params: 5,124
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_train
# Out:
# array([[-2.04641954,  0.69523492, -0.42754833,  0.49802748],
#        [ 0.69523492, -0.42754833,  0.49802748,  0.05977726],
#        [-0.42754833,  0.49802748,  0.05977726, -1.27423201],
#        ...,
#        [-2.37662824,  1.15559387,  1.77271934,  0.247576  ],
#        [ 1.15559387,  1.77271934,  0.247576  , -2.66410762],
#        [ 1.77271934,  0.247576  , -2.66410762, -0.20797311]])

# %%
X_train
# Out:
# array([[[ 1.78701996],
#         [ 0.15026228],
#         [ 0.30875418],
#         ...,
#         [-0.34819034],
#         [ 1.74441701],
#         [-1.48451102]],
#
#        [[ 0.15026228],
#         [ 0.30875418],
#         [ 0.69140363],
#         ...,
#         [ 1.74441701],
#         [-1.48451102],
#         [-2.04641954]],
#
#        [[ 0.30875418],
#         [ 0.69140363],
#         [-1.35034036],
#         ...,
#         [-1.48451102],
#         [-2.04641954],
#         [ 0.69523492]],
#
#        ...,
#
#        [[ 1.47744578],
#         [-0.16251616],
#         [ 0.01320951],
#         ...,
#         [ 0.193245  ],
#         [ 1.63587745],
#         [ 0.80289034]],
#
#        [[-0.16251616],
#         [ 0.01320951],
#         [-0.29495225],
#         ...,
#         [ 1.63587745],
#         [ 0.80289034],
#         [-2.37662824]],
#
#        [[ 0.01320951],
#         [-0.29495225],
#         [-1.92680635],
#         ...,
#         [ 0.80289034],
#         [-2.37662824],
#         [ 1.15559387]]])

# %% [markdown]
# ### Compile and fit the model

# %%
# compile and fit
rnn.compile(optimizer = 'nadam', loss = 'mean_squared_error')
rnn_hist = rnn.fit(X_train, y_train, epochs=300, validation_split=0.1, verbose=1)
# Out:
# Train on 531 samples, validate on 60 samples
# Epoch 1/300
# 531/531 [==============================] - 3s 6ms/step - loss: 0.7839 - val_loss: 0.9591
# Epoch 2/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7766 - val_loss: 0.9724
# Epoch 3/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7820 - val_loss: 0.9535
# Epoch 4/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7903 - val_loss: 0.9589
# Epoch 5/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7827 - val_loss: 0.9741
# Epoch 6/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7827 - val_loss: 0.9701
# Epoch 7/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7890 - val_loss: 0.9622
# Epoch 8/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7969 - val_loss: 0.9606
# Epoch 9/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7990 - val_loss: 1.1306
# Epoch 10/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7990 - val_loss: 0.9652
# Epoch 11/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7904 - val_loss: 0.9649
# Epoch 12/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7916 - val_loss: 0.9790
# Epoch 13/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7842 - val_loss: 0.9703
# Epoch 14/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7819 - val_loss: 0.9802
# Epoch 15/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7864 - val_loss: 0.9920
# Epoch 16/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7956 - val_loss: 0.9890
# Epoch 17/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7840 - val_loss: 0.9787
# Epoch 18/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7977 - val_loss: 0.9759
# Epoch 19/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7747 - val_loss: 0.9842
# Epoch 20/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7877 - val_loss: 1.0033
# Epoch 21/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7918 - val_loss: 0.9830
# Epoch 22/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7674 - val_loss: 1.0389
# Epoch 23/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7867 - val_loss: 0.9877
# Epoch 24/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7828 - val_loss: 0.9776
# Epoch 25/300
# 531/531 [==============================] - 1s 2ms/step - loss: 0.7748 - val_loss: 1.0387
# Epoch 26/300
# 531/531 [==============================] - 1s 2ms/step - loss: 0.7892 - val_loss: 1.0696
# Epoch 27/300
# 531/531 [==============================] - 1s 2ms/step - loss: 0.7731 - val_loss: 0.9980
# Epoch 28/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7886 - val_loss: 0.9863
# Epoch 29/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7917 - val_loss: 0.9716
# Epoch 30/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7743 - val_loss: 0.9807
# Epoch 31/300
# 531/531 [==============================] - 1s 2ms/step - loss: 0.7675 - val_loss: 0.9796
# Epoch 32/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7750 - val_loss: 0.9826
# Epoch 33/300
# 531/531 [==============================] - 1s 2ms/step - loss: 0.7893 - val_loss: 0.9696
# Epoch 34/300
# 531/531 [==============================] - 1s 2ms/step - loss: 0.7758 - val_loss: 0.9958
# Epoch 35/300
# 531/531 [==============================] - 1s 2ms/step - loss: 0.7703 - val_loss: 1.0029
# Epoch 36/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7719 - val_loss: 0.9821
# Epoch 37/300
# 531/531 [==============================] - 1s 2ms/step - loss: 0.7686 - val_loss: 0.9733
# Epoch 38/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7571 - val_loss: 0.9876
# Epoch 39/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7651 - val_loss: 0.9991
# Epoch 40/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7871 - val_loss: 0.9999
# Epoch 41/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7711 - val_loss: 1.0254
# Epoch 42/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7789 - val_loss: 1.0040
# Epoch 43/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7812 - val_loss: 0.9891
# Epoch 44/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7763 - val_loss: 1.0105
# Epoch 45/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7567 - val_loss: 0.9954
# Epoch 46/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7702 - val_loss: 0.9805
# Epoch 47/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7839 - val_loss: 1.0677
# Epoch 48/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7730 - val_loss: 1.0184
# Epoch 49/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7627 - val_loss: 0.9840
# Epoch 50/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7673 - val_loss: 1.0295
# Epoch 51/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7497 - val_loss: 0.9902
# Epoch 52/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7626 - val_loss: 0.9820
# Epoch 53/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7622 - val_loss: 0.9942
# Epoch 54/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7665 - val_loss: 1.0021
# Epoch 55/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7507 - val_loss: 0.9904
# Epoch 56/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7638 - val_loss: 0.9927
# Epoch 57/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7530 - val_loss: 1.0231
# Epoch 58/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7641 - val_loss: 0.9944
# Epoch 59/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7546 - val_loss: 0.9951
# Epoch 60/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7658 - val_loss: 0.9965
# Epoch 61/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7543 - val_loss: 1.0656
# Epoch 62/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7610 - val_loss: 1.0389
# Epoch 63/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7731 - val_loss: 1.0003
# Epoch 64/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7645 - val_loss: 1.0562
# Epoch 65/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7657 - val_loss: 0.9811
# Epoch 66/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7748 - val_loss: 0.9767
# Epoch 67/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7659 - val_loss: 0.9982
# Epoch 68/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7593 - val_loss: 0.9897
# Epoch 69/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7432 - val_loss: 1.0657
# Epoch 70/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7680 - val_loss: 0.9821
# Epoch 71/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7596 - val_loss: 1.0001
# Epoch 72/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7495 - val_loss: 0.9965
# Epoch 73/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7451 - val_loss: 0.9655
# Epoch 74/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7567 - val_loss: 0.9733
# Epoch 75/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7565 - val_loss: 0.9781
# Epoch 76/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7554 - val_loss: 1.0063
# Epoch 77/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7482 - val_loss: 0.9849
# Epoch 78/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7572 - val_loss: 0.9816
# Epoch 79/300
# 531/531 [==============================] - 1s 2ms/step - loss: 0.7664 - val_loss: 0.9638
# Epoch 80/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7511 - val_loss: 0.9729
# Epoch 81/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7623 - val_loss: 0.9667
# Epoch 82/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7569 - val_loss: 0.9977
# Epoch 83/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7351 - val_loss: 0.9907
# Epoch 84/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7534 - val_loss: 1.0425
# Epoch 85/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7677 - val_loss: 1.0009
# Epoch 86/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7610 - val_loss: 1.0159
# Epoch 87/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7525 - val_loss: 1.0089
# Epoch 88/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7584 - val_loss: 0.9817
# Epoch 89/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7615 - val_loss: 1.0844
# Epoch 90/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7685 - val_loss: 1.0276
# Epoch 91/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7761 - val_loss: 0.9944
# Epoch 92/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7557 - val_loss: 1.0212
# Epoch 93/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7539 - val_loss: 0.9776
# Epoch 94/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7562 - val_loss: 0.9796
# Epoch 95/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7557 - val_loss: 1.0064
# Epoch 96/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7482 - val_loss: 0.9837
# Epoch 97/300
# 531/531 [==============================] - 1s 2ms/step - loss: 0.7548 - val_loss: 0.9804
# Epoch 98/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7915 - val_loss: 0.9590
# Epoch 99/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7641 - val_loss: 1.0262
# Epoch 100/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7557 - val_loss: 1.0052
# Epoch 101/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7691 - val_loss: 1.0111
# Epoch 102/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7517 - val_loss: 0.9953
# Epoch 103/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7472 - val_loss: 0.9944
# Epoch 104/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7458 - val_loss: 1.0223
# Epoch 105/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7466 - val_loss: 1.0259
# Epoch 106/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7391 - val_loss: 1.0161
# Epoch 107/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7614 - val_loss: 0.9870
# Epoch 108/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7511 - val_loss: 1.0082
# Epoch 109/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7544 - val_loss: 1.0182
# Epoch 110/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7368 - val_loss: 0.9915
# Epoch 111/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7407 - val_loss: 0.9855
# Epoch 112/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7298 - val_loss: 1.0645
# Epoch 113/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7465 - val_loss: 1.0469
# Epoch 114/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7343 - val_loss: 0.9945
# Epoch 115/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7469 - val_loss: 1.0622
# Epoch 116/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7371 - val_loss: 1.1082
# Epoch 117/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7575 - val_loss: 1.1110
# Epoch 118/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7438 - val_loss: 1.0652
# Epoch 119/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7330 - val_loss: 1.0048
# Epoch 120/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7418 - val_loss: 0.9969
# Epoch 121/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7500 - val_loss: 0.9778
# Epoch 122/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7317 - val_loss: 0.9818
# Epoch 123/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7387 - val_loss: 0.9653
# Epoch 124/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7446 - val_loss: 1.0271
# Epoch 125/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7509 - val_loss: 0.9886
# Epoch 126/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7222 - val_loss: 0.9978
# Epoch 127/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7362 - val_loss: 0.9729
# Epoch 128/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7388 - val_loss: 0.9822
# Epoch 129/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7265 - val_loss: 0.9787
# Epoch 130/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7388 - val_loss: 1.0002
# Epoch 131/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7284 - val_loss: 1.0630
# Epoch 132/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7550 - val_loss: 1.0432
# Epoch 133/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7485 - val_loss: 0.9983
# Epoch 134/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7577 - val_loss: 1.0203
# Epoch 135/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7405 - val_loss: 1.0027
# Epoch 136/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7213 - val_loss: 1.0113
# Epoch 137/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7281 - val_loss: 1.0274
# Epoch 138/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7195 - val_loss: 1.0305
# Epoch 139/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7457 - val_loss: 1.0967
# Epoch 140/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7379 - val_loss: 0.9973
# Epoch 141/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7338 - val_loss: 0.9893
# Epoch 142/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7268 - val_loss: 0.9921
# Epoch 143/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7308 - val_loss: 0.9872
# Epoch 144/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7301 - val_loss: 0.9977
# Epoch 145/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7154 - val_loss: 0.9990
# Epoch 146/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7257 - val_loss: 0.9780
# Epoch 147/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7148 - val_loss: 0.9776
# Epoch 148/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7533 - val_loss: 0.9809
# Epoch 149/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7251 - val_loss: 0.9901
# Epoch 150/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7291 - val_loss: 0.9866
# Epoch 151/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7464 - val_loss: 0.9808
# Epoch 152/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7456 - val_loss: 0.9675
# Epoch 153/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7337 - val_loss: 0.9896
# Epoch 154/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7140 - val_loss: 1.0046
# Epoch 155/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7323 - val_loss: 1.0008
# Epoch 156/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7323 - val_loss: 0.9783
# Epoch 157/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7112 - val_loss: 0.9822
# Epoch 158/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7114 - val_loss: 0.9939
# Epoch 159/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7301 - val_loss: 0.9853
# Epoch 160/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7297 - val_loss: 0.9823
# Epoch 161/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7232 - val_loss: 0.9837
# Epoch 162/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7126 - val_loss: 0.9496
# Epoch 163/300
# 531/531 [==============================] - 1s 2ms/step - loss: 0.7307 - val_loss: 0.9847
# Epoch 164/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7331 - val_loss: 0.9674
# Epoch 165/300
# 531/531 [==============================] - 1s 2ms/step - loss: 0.7248 - val_loss: 0.9782
# Epoch 166/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7106 - val_loss: 0.9699
# Epoch 167/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7186 - val_loss: 1.0032
# Epoch 168/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7146 - val_loss: 0.9890
# Epoch 169/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7100 - val_loss: 1.0021
# Epoch 170/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7143 - val_loss: 1.0021
# Epoch 171/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7257 - val_loss: 1.0135
# Epoch 172/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7220 - val_loss: 0.9895
# Epoch 173/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7244 - val_loss: 0.9878
# Epoch 174/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7507 - val_loss: 1.0057
# Epoch 175/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7179 - val_loss: 0.9892
# Epoch 176/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7299 - val_loss: 1.0327
# Epoch 177/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7315 - val_loss: 1.1333
# Epoch 178/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7175 - val_loss: 0.9937
# Epoch 179/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7268 - val_loss: 1.0371
# Epoch 180/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7294 - val_loss: 1.0046
# Epoch 181/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7169 - val_loss: 0.9890
# Epoch 182/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7278 - val_loss: 0.9708
# Epoch 183/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7221 - val_loss: 0.9650
# Epoch 184/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7230 - val_loss: 1.0146
# Epoch 185/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7018 - val_loss: 1.0539
# Epoch 186/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7235 - val_loss: 0.9999
# Epoch 187/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7155 - val_loss: 1.0364
# Epoch 188/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6978 - val_loss: 0.9793
# Epoch 189/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7276 - val_loss: 0.9802
# Epoch 190/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7319 - val_loss: 0.9976
# Epoch 191/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7153 - val_loss: 1.0104
# Epoch 192/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7207 - val_loss: 0.9702
# Epoch 193/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7259 - val_loss: 0.9944
# Epoch 194/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7119 - val_loss: 0.9817
# Epoch 195/300
# 531/531 [==============================] - 1s 2ms/step - loss: 0.7224 - val_loss: 0.9810
# Epoch 196/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7142 - val_loss: 0.9830
# Epoch 197/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7076 - val_loss: 0.9732
# Epoch 198/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7288 - val_loss: 0.9812
# Epoch 199/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7033 - val_loss: 0.9696
# Epoch 200/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7304 - val_loss: 0.9894
# Epoch 201/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7002 - val_loss: 0.9488
# Epoch 202/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7094 - val_loss: 0.9343
# Epoch 203/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7192 - val_loss: 0.9681
# Epoch 204/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7024 - val_loss: 0.9864
# Epoch 205/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7209 - val_loss: 0.9663
# Epoch 206/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7143 - val_loss: 0.9858
# Epoch 207/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7189 - val_loss: 0.9776
# Epoch 208/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7104 - val_loss: 0.9779
# Epoch 209/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7226 - val_loss: 0.9738
# Epoch 210/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7076 - val_loss: 0.9822
# Epoch 211/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7039 - val_loss: 0.9871
# Epoch 212/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7042 - val_loss: 1.0234
# Epoch 213/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7038 - val_loss: 0.9961
# Epoch 214/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7042 - val_loss: 1.0069
# Epoch 215/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7204 - val_loss: 0.9784
# Epoch 216/300
# 531/531 [==============================] - 1s 2ms/step - loss: 0.7050 - val_loss: 1.0244
# Epoch 217/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7115 - val_loss: 0.9824
# Epoch 218/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7100 - val_loss: 0.9496
# Epoch 219/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6976 - val_loss: 0.9859
# Epoch 220/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6794 - val_loss: 0.9589
# Epoch 221/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7025 - val_loss: 0.9537
# Epoch 222/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7125 - val_loss: 0.9556
# Epoch 223/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7015 - val_loss: 0.9885
# Epoch 224/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6995 - val_loss: 0.9554
# Epoch 225/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6957 - val_loss: 0.9779
# Epoch 226/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7233 - val_loss: 0.9699
# Epoch 227/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6945 - val_loss: 0.9956
# Epoch 228/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7001 - val_loss: 1.0037
# Epoch 229/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7087 - val_loss: 0.9976
# Epoch 230/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7110 - val_loss: 0.9721
# Epoch 231/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7123 - val_loss: 0.9796
# Epoch 232/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7101 - val_loss: 0.9616
# Epoch 233/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6900 - val_loss: 0.9678
# Epoch 234/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7138 - val_loss: 0.9456
# Epoch 235/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7029 - val_loss: 0.9555
# Epoch 236/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7103 - val_loss: 0.9626
# Epoch 237/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7191 - val_loss: 0.9889
# Epoch 238/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6940 - val_loss: 0.9589
# Epoch 239/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6911 - val_loss: 0.9647
# Epoch 240/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6772 - val_loss: 1.0047
# Epoch 241/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7092 - val_loss: 0.9673
# Epoch 242/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6938 - val_loss: 0.9728
# Epoch 243/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6951 - val_loss: 0.9551
# Epoch 244/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6776 - val_loss: 0.9723
# Epoch 245/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6951 - val_loss: 0.9602
# Epoch 246/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6959 - val_loss: 0.9556
# Epoch 247/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7046 - val_loss: 0.9723
# Epoch 248/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7003 - val_loss: 0.9637
# Epoch 249/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6972 - val_loss: 0.9751
# Epoch 250/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6893 - val_loss: 0.9759
# Epoch 251/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6853 - val_loss: 0.9677
# Epoch 252/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7020 - val_loss: 0.9968
# Epoch 253/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7009 - val_loss: 0.9788
# Epoch 254/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7044 - val_loss: 0.9674
# Epoch 255/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7013 - val_loss: 0.9727
# Epoch 256/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6745 - val_loss: 0.9766
# Epoch 257/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6994 - val_loss: 0.9734
# Epoch 258/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6952 - val_loss: 0.9614
# Epoch 259/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6834 - val_loss: 0.9904
# Epoch 260/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6775 - val_loss: 1.0128
# Epoch 261/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6987 - val_loss: 0.9716
# Epoch 262/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6888 - val_loss: 0.9649
# Epoch 263/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7082 - val_loss: 0.9640
# Epoch 264/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7203 - val_loss: 0.9750
# Epoch 265/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6871 - val_loss: 0.9750
# Epoch 266/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6951 - val_loss: 1.0508
# Epoch 267/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6761 - val_loss: 1.0307
# Epoch 268/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7006 - val_loss: 0.9964
# Epoch 269/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6878 - val_loss: 0.9793
# Epoch 270/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6877 - val_loss: 0.9594
# Epoch 271/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6805 - val_loss: 0.9641
# Epoch 272/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6823 - val_loss: 0.9778
# Epoch 273/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6890 - val_loss: 0.9844
# Epoch 274/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6813 - val_loss: 0.9963
# Epoch 275/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6823 - val_loss: 0.9624
# Epoch 276/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6768 - val_loss: 1.0285
# Epoch 277/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6854 - val_loss: 0.9849
# Epoch 278/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6938 - val_loss: 0.9988
# Epoch 279/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6765 - val_loss: 1.0012
# Epoch 280/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6860 - val_loss: 1.0010
# Epoch 281/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6910 - val_loss: 0.9793
# Epoch 282/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6970 - val_loss: 1.0187
# Epoch 283/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6955 - val_loss: 1.0002
# Epoch 284/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6961 - val_loss: 0.9754
# Epoch 285/300
# 531/531 [==============================] - 1s 2ms/step - loss: 0.6867 - val_loss: 0.9903
# Epoch 286/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6742 - val_loss: 0.9993
# Epoch 287/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6899 - val_loss: 1.0007
# Epoch 288/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6900 - val_loss: 0.9783
# Epoch 289/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6594 - val_loss: 0.9889
# Epoch 290/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6748 - val_loss: 0.9808
# Epoch 291/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6755 - val_loss: 0.9865
# Epoch 292/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6759 - val_loss: 0.9592
# Epoch 293/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6596 - val_loss: 0.9785
# Epoch 294/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6816 - val_loss: 1.0039
# Epoch 295/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6909 - val_loss: 0.9526
# Epoch 296/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6870 - val_loss: 1.0084
# Epoch 297/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.7029 - val_loss: 0.9830
# Epoch 298/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6784 - val_loss: 0.9900
# Epoch 299/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6916 - val_loss: 0.9797
# Epoch 300/300
# 531/531 [==============================] - 1s 1ms/step - loss: 0.6865 - val_loss: 0.9679

# %% [markdown]
# ### Evaluate the model

# %%
X_test, y_test = [], []
for i in range(X_size, len(temp[607:])-3):
    X_test.append(temp[i-X_size+607:i+607,0])
    y_test.append(temp[i+607:i+y_size+607,0])
    
X_test, y_test = np.array(X_test), np.array(y_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
# Check the input and output shape for LSTM.
print('The shape of input matrix X is {}'.format(X_test.shape))
print('The shape of target matrix y is {}'.format(y_test.shape))
# Out:
# The shape of input matrix X is (46, 16, 1)
# The shape of target matrix y is (46, 4)

# %%
y_pred = rnn.predict(X_test, verbose=0)
y_pred
# Out:
# array([[ 6.10323012e-01,  4.88931358e-01,  4.35413003e-01,
#          4.25683051e-01],
#        [ 5.67774653e-01,  6.05293691e-01,  4.83841181e-01,
#          4.10132647e-01],
#        [ 9.63810623e-01,  8.22905958e-01,  6.80615187e-01,
#          7.21084714e-01],
#        [ 7.17242897e-01,  8.15525472e-01,  5.57145774e-01,
#          4.32905704e-01],
#        [ 3.69680345e-01,  5.27446568e-01,  2.74881661e-01,
#          1.53717548e-01],
#        [ 4.47186768e-01,  4.60197687e-01,  1.95366085e-01,
#          1.60405666e-01],
#        [ 1.55004755e-01,  1.77021369e-01,  6.03666604e-02,
#          1.41393661e-01],
#        [ 9.63531435e-02,  2.04859167e-01,  2.14616120e-01,
#          2.27173030e-01],
#        [ 2.91508555e-01,  4.91670489e-01,  2.25205392e-01,
#         -2.94647738e-02],
#        [ 1.16892159e+00,  4.09624368e-01, -3.55935246e-02,
#          6.40150979e-02],
#        [ 5.88049471e-01, -5.45354821e-02,  1.72111973e-01,
#          4.82372791e-01],
#        [-3.78203392e-03, -7.23201782e-02,  1.40800342e-01,
#          3.44410598e-01],
#        [ 8.18892717e-01,  3.33506346e-01,  2.58592337e-01,
#          4.25972611e-01],
#        [ 1.10561633e+00,  7.09444106e-01,  3.88881177e-01,
#          4.65708405e-01],
#        [ 8.91906440e-01,  9.22501147e-01,  6.60609126e-01,
#          5.63270867e-01],
#        [ 5.90003192e-01,  7.56921172e-01,  6.52092278e-01,
#          5.58015108e-01],
#        [ 3.82194102e-01,  7.44179547e-01,  5.72457910e-01,
#          3.63150716e-01],
#        [ 4.22468245e-01,  6.79783762e-01,  4.41167355e-01,
#          2.43230015e-01],
#        [-3.06953967e-01, -3.53416920e-01,  2.25537419e-01,
#          4.49204773e-01],
#        [-8.32635909e-02,  2.05516830e-01,  8.91301751e-01,
#          7.32904613e-01],
#        [ 1.09575912e-02,  3.93667608e-01,  2.86601961e-01,
#          4.17402312e-02],
#        [-1.03649646e-01,  2.30078101e-02,  1.85833126e-03,
#          1.18194751e-01],
#        [-2.08421066e-01, -2.30815426e-01,  5.81969023e-02,
#          2.70003706e-01],
#        [-1.87757507e-01, -8.93356949e-02,  4.88863528e-01,
#          5.05741537e-01],
#        [-1.97455794e-01,  2.98769712e-01,  6.54414237e-01,
#          3.24578822e-01],
#        [-2.29932740e-02,  2.95629740e-01,  3.87823433e-01,
#          1.94809586e-01],
#        [ 3.75150800e-01,  4.18993413e-01,  2.57044375e-01,
#          1.66811079e-01],
#        [ 2.64666975e-01,  2.58880377e-01,  8.52951109e-02,
#          1.66868940e-02],
#        [ 1.25142947e-01,  2.61394501e-01, -1.30976252e-02,
#         -1.38580233e-01],
#        [ 1.64344564e-01,  1.33190572e-01, -2.98245996e-02,
#         -2.30181478e-02],
#        [ 3.63695860e-01,  1.05872273e-01, -3.96920145e-02,
#          3.67245600e-02],
#        [ 4.52107608e-01,  1.17907271e-01,  1.93034559e-02,
#          1.35698318e-01],
#        [ 5.35358310e-01,  2.35699356e-01,  1.56131417e-01,
#          2.59490520e-01],
#        [ 5.04523993e-01,  4.28571224e-01,  3.86763036e-01,
#          3.81819367e-01],
#        [ 4.93302941e-01,  3.85386109e-01,  5.17741799e-01,
#          5.55798888e-01],
#        [ 2.14499086e-02,  2.01478302e-01,  5.95913947e-01,
#          4.95414168e-01],
#        [-2.59749770e-01, -1.24274597e-01, -3.12271044e-02,
#         -3.14993411e-03],
#        [-2.63164401e-01, -3.16696502e-02, -7.28860497e-04,
#          7.64751658e-02],
#        [-1.18736006e-01, -2.18096860e-02,  1.78789079e-01,
#          3.49362761e-01],
#        [-9.36257541e-02, -2.23195702e-02,  3.89206886e-01,
#          5.18088698e-01],
#        [ 9.36447084e-03,  1.26623288e-01,  3.58274519e-01,
#          3.71767879e-01],
#        [ 5.42586446e-02,  5.33929408e-01,  3.48978221e-01,
#         -3.99524048e-02],
#        [ 6.64794683e-01,  5.89644790e-01, -5.64066321e-02,
#         -2.62909353e-01],
#        [ 5.95834076e-01,  9.67148542e-02, -2.69657493e-01,
#         -1.48920357e-01],
#        [ 4.00751829e-02,  1.04484379e-01, -1.46942332e-01,
#         -2.52395809e-01],
#        [ 3.21042240e-02,  8.57164562e-02, -2.32877970e-01,
#         -2.42782891e-01]], dtype=float32)

# %%
# Compute the out-of-sample actual and predicted 2-day, 3-day, ..., N-day return, 
# by summing 1-day forward returns up to this horizon.
for i in range(len(y_pred)):
    y_test[i] = y_test[i].cumsum()
    y_pred[i] = y_pred[i].cumsum()

# %% [markdown]
# #### RSME

# %%
# Calculate the RMSE between actual and predicted 1-day, 2-day, ..., N-day returns.
RMSE = []
for i in range(y_size):
    RMSE.append(np.sqrt(mean_squared_error(y_test[:,i], y_pred[:,i])))

for i in range(y_size):
    print('The '+str(i+1)+'-day RMSE between actual and predicted is {0:.4f}'.format(RMSE[i]))
# Out:
# The 1-day RMSE between actual and predicted is 1.1749
# The 2-day RMSE between actual and predicted is 1.6824
# The 3-day RMSE between actual and predicted is 1.8790
# The 4-day RMSE between actual and predicted is 2.0624

# %% [markdown]
# #### Correlation

# %%
# Calculate the correlation between actual and predicted 1-day, 2-day, ..., N-day returns.
corr = []
for i in range(y_size):
    corr.append(np.corrcoef(y_test[:,i], y_pred[:,i])[0][1])

for i in range(y_size):
    print('The '+str(i+1)+'-day correlation between actual and predicted is {0:.4f}'.format(corr[i]))
# Out:
# The 1-day correlation between actual and predicted is 0.1141
# The 2-day correlation between actual and predicted is 0.2002
# The 3-day correlation between actual and predicted is 0.3443
# The 4-day correlation between actual and predicted is 0.4229

# %% [markdown]
# #### Plotting

# %%
# Plot the actual and predicted returns in the out-of-sample part.
_, ax = plt.subplots(nrows=1, ncols=4,figsize=(24,4))
for i in range(y_size):
    ax[i].set_title(str(i+1)+'-day actual and predicted return')
    ax[i].plot(y_test[:,i],label='Actual')
    ax[i].plot(y_pred[:,i],label='Predicted')
    ax[i].legend()

# %% [markdown]
# ## Conclusions

# %% [markdown]
# The quality of the prediction isn't really good.
# - The RMSE increased from 1.10 to 1.80 as the returns cumulated. However, we've scaled the returns to fit for the LSTM model and such amount of RMSE isn't actually promising.
# - The correlation grew from 0.11 to 0.42, which means the predictions of cumulative returns become more useful as time goes by but still cannot be seen as a good result.
# - From the figure above, we learn that our prediciton gradually fits the actual returns as the the cumulates. However, we cannot say the quality of prediction is good.
